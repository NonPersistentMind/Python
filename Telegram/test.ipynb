# %%
import numpy as np
from PIL import Image
from img_processing_utils import *

img = np.array(Image.open(source_folder+'file_0.jpg'))
img_enc = np.array(Image.open(dest_folder+'file_0_encoded.jpg'))

# %%
img
# Out:
# array([[[250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250],
#         ...,
#         [250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250]],
#
#        [[250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250],
#         ...,
#         [250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250]],
#
#        [[250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250],
#         ...,
#         [250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img_enc
# Out:
# array([[[250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250],
#         ...,
#         [250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250]],
#
#        [[250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250],
#         ...,
#         [250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250]],
#
#        [[250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250],
#         ...,
#         [250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...
