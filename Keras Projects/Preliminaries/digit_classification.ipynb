# %%
from keras.datasets import mnist
from keras import models
from keras import layers
from keras.utils import to_categorical
import numpy as np
from matplotlib import pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
test_images.shape
# train_images = train_images.reshape((60000, 28*28))
# train_images = train_images.astype('float32')/255

test_images = test_images.reshape((10000, 28*28))
test_images = test_images.astype('float32')/255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(28*28,)))
network.add(layers.Dense(10, activation='softmax'))

network.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

network.fit(train_images,train_labels, epochs=10, batch_size=128)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 4s 7ms/step - loss: 0.4168 - accuracy: 0.8796
# Epoch 2/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1103 - accuracy: 0.9676
# Epoch 3/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0695 - accuracy: 0.9791
# Epoch 4/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0484 - accuracy: 0.9860
# Epoch 5/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0347 - accuracy: 0.9895
# Epoch 6/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0265 - accuracy: 0.9921
# Epoch 7/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0212 - accuracy: 0.9941
# Epoch 8/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0167 - accuracy: 0.9955
# Epoch 9/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0123 - accuracy: 0.9966
# Epoch 10/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0103 - accuracy: 0.9969

# %%
test_loss, test_accuracy = network.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0691 - accuracy: 0.9816

# %%
# network.evaluate(test_images, test_labels)
np.argmax(network.predict(test_images)[0])
# Out:
# 7

# %%
plt.imshow(train_images[123], cmap='CMRmap_r')
